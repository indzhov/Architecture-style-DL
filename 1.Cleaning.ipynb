# %% [markdown]
# # Architecture style Classifier
# by Dimitar Indzhov
#
# # Abstract
# This project is inspired from the paper by Zhe Xu, called "*Architectural Style Classification using Multinomial Latent Logistic Regression*". The main goal is to be build a classifier, which can detect the architectural styles of buildings. For the purpose, a deep neural network will be used. The AI model will be trained with a mixed dataset from google, the official one used in the paper, and other people's projects. The very data set aims to be the best one, amongst the ones, which can be found on the Internet.
#
# The final product is supposed to be an application, which everyone can use. For instance, if you are on a vacation abroad and wonder in what atchitecture styles are the building, which you are admiring on the high street. Then, you will be able just to pick up your phone, take a picture and find the answer within seconds. The prediction page will include information about the style, instead of only showing to which architecture class it belongs.
#
# # Additional sources :
# [The app ](https://architecture-classifier.herokuapp.com/)
#
# [Official page ](https://indzhov.github.io/Architecture-style-DL/)
#
# [Official repository ](https://github.com/indzhov/Architecture-style-DL)
#
# [The data ](https://architecture-classifier.herokuapp.com/)
#
#
# # Content:
#
# The project will be separated in 6 stages  (5 different notebooks and 1 folder for the app). This is needed as the projcet is done with Google Colab, and some of the notebooks requred so much RAM, that it was not impossible to be done everything in a signle notebok.
#
# 1. Cleaning
# 2. Preprocessing
# 3. Visualizatios (EDA)
# 4. ResNet Training
# 5. Inception Training
# 6. Building an app
#
# # This Firt notebook includes also some additional sections as :
#
# 1. Research of papers and other's people work and writings about the problem.
# 2. Considerate description of the problem, as this is not a simple image classifier task.
# 3. Considerate description of the data set, sources and the gathering of the data.
# 4. At the end we are going to look briefly into the solution or methods that could be used later.
# 5. The final result will be an appropriate dataset, that is sutable to go into preprocessing in the next notebook.
#
# # A few words from the author:
# The objective of this task is pretty hard to be rached. The problems are numerous and we are going to try to solve them as much as possible. However, it is good to bear in mind that this is not a simple classification problem. For instance, we are not going to predict only if there is a building in a particular photo. In case to recognize the different architectural styles, our model have to look not only at the types, shapes, colors of the building, but also to keep attention to the different facades and ornaments. Not to mention, that some examples like the Egyptian ones, could not be classified as building at all, they have pyramids and statues of sphinxes. Even if we find a solution to recognize and classify those things, we wont have a valid classification in any case. Hypothetically, even when we can classify the visual appearance of the building on a hundred percent, it wont be true in the real life. This is because, apart from the style almost any civlization or country have contributed on every building with their own touches. Thus, a specific architecture could looks slightly different in two separated countries. Also, the historical time in which they were built also could impact slightly the visual appearance. Another problem are the influences. For example, we have "International style", which presents the buildings in the modern and big cities, like New York. Those buildings are usually skyscrapers. However,not only each of them is different to any other, but their heigh is varying in every country, city or district. Another examples, is the "revival" architectures. Those are buildings which were build more recently than the time from which the original style comes. Those kind of architectures could be influenced from the ancient civilizations and built nowadays. The Greeks influenced the Romans, which in turn brough their forms into the British Islands from where we can see their contribution all over the world. Thus, the Greek Revival's features could be seen not only in different places, from different historical time, but also in other styles that are not generally "Greek ones". There is also a problem with the refurbishment, or the damage done to some buildings through the ages. For instance, Hagia Sophia is perfect example of Byzantine architecture, but there is no even a single photo without the minarets, which are more common, for the Arabic architectures, but were added to Haghia Sophia, after the Ottomans seiged and took over the city of Constantinopol in 15th century. Then the building were changed from a Church to a Mosque. With all of that being said, it is clear that the task of classifying architectures equally and accuratelly become very hard. For that reason, a person with architectural, cultural or art historical knowledge is needed, especially in the preparing of the data from which our model will learn.
#
# # Other peoples contributed to similar tasks.
#
# 1. Zhe Xu - [*Architectural Style Classification using Multinomial Latent Logistic Regression*](https://opus.lib.uts.edu.au/bitstream/10453/122547/1/Architectural%20Style%20Classification%20using%20Multinomial%20Latent%20Logistic%20Regression.pdf) - In this paper, the author not only give the [data set](https://www.kaggle.com/wwymak/architecture-dataset), they were using, but also proposes the approaches in which the task could be solved . Also, it is stated that, the exposed approach "obtains the best classification results". Briefly, he was using Deformable Part-based Models (DPM) and  Multinomial  Latent  Logistic  Regression  (MLLR). However, the paper is not dedicated to a specific programming leanguage or technology. Thus, those ones are more sutable and well known in R, than they are acessible in Python or Tensorflow (on which project is based). However, we are going to look at the ideas, try to understand how they work and come up with a solution or alternative, easily applicable in the technologies we had choose.
# The papers itself is inspired from another findings. like the possibility  of  cross-domainmatching from sketches to building images. Zhe Xu used that, to solve the problem with representing features, like the building fa ̧cades. The proposed algorithm, MLLR, uses latent variables. They could be use in other problems, like image captioning, where they are explained in the following way : "targeted partial caption in-dicates that the words at some locations are observed, whilethe words at other locations are not specified,i.e., latent" [1] The Latent variables arise mainly, but not exclusively, in the social sciences. This is because social science often deals in concepts which are constructs rather than the directly measurable variables which are typical of physical sciences. Clearly, they are variables that are not directly observed but are rather inferred (through a mathematical model) from other variables that are observed (directly measured). Thus, they can change their attitude (values) in different situations.
# In the paper, Zhe Xu, explains it visually, as well :
#
# ![Screenshot from 2021-02-09 20-47-44.png](data:image/png;base64,...)
# In the middlefigure,  the  smaller  marks  that  surround  the  larger  marks  represent  possible  latent values for an object.
#   Despite the good results, the author points the same as we have done before this section :
#
#   "*An  architectural  style  is  a  specific  construction,  characterized  by  its  notablefeatures. For instance, unique features, such as pointed arches, rib vaults, rosewindows and ornate fa ̧cades, make it possible to distinguish the Gothic style from other styles. Architectural history has dictated that there are complicated inter-relationships between different styles, including rebellion, special territoriality,revivals, and re-interpretations. As a consequence, it is difficult to strictly classify two styles using a standard criterion.*"
#
#   The cross-relationship is also illustrated in this picture :
#
# ![Screenshot from 2021-02-09 20-57-47.png](data:image/png;base64,...)
#
#
# As the MLLR approach is very hard for implementation in Tensorflow , we are going to research other alternatives. However, from this paper we will get the dataset and the intuition of the latent variable
#
#
#
# [1] Exact Adversarial Attack to Image Captioning via Structured Output Learning with Latent Variables (p.2, [link](https://arxiv.org/pdf/1905.04016v1.pdf))

# %% [markdown]
# 2. Kenny Leung - [Classification of Architectural Styles Using Neural Networks](https://kennythedatascientist.weebly.com/blog/classification-of-architectural-styles-using-neural-networks?fbclid=IwAR2TMuW2rcNRqNV6H8z7aDrRxvTZ3_m7X4NL63lVggGvAk8frW-ZrlhQAvo) - For his project, Kenny used only 9 classes, however he again encounter the problem with the dificult assignation of features to particular style, that we mentioned above, as he points it : "Architectural styles often build on one another, with each past period providing inspiration for the next culture." In this project, the method is slightly different and easier for implementation. He used Transfer Learning. He choose the InceptionV3 pre-trained model. It is appropriate choice, as InceptionV3 is less expensive in terms of memory and time than other models, like VGG16 (for example). Also, it uses convolutions of different sizes to capture details at varied scales(5X5, 3X3, 1X1).The main characteristic of the module is that filterswith different sizes are used in the same layer. This leads to a different size of the extracted patterns,as well as more exhaustive information[2].
#
# [2] [Deep Learning for Feature Extraction in RemoteSensing: A Case-Study of Aerial Scene Classification](https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&ved=2ahUKEwiTjvqY393uAhWVQkEAHex3ARAQFjASegQIIBAC&url=https%3A%2F%2Fwww.mdpi.com%2F1424-8220%2F20%2F14%2F3906%2Fpdf&usg=AOvVaw0R9RW8VJ3uA0LF7WaRbbKQ) (p.4)

# %% [markdown]
# 3. Kurt McIntire - [Building an image recognition model to classify home types](https://kurtmcintire.com/image-recognition-homes/?fbclid=IwAR0aC41yU4hGn4QkwzwrtjU1aF4vZFp189J37DYc7zMLcYsZ_Tq1TXgdZwk) - In his project Kurt tries to detect more architectural differences betwen homes, then our whole spectre of buildings, which invloves cathedrals, skyscrapers and so on, however he is proposing very appropriate things. For instance, his model is based on ResNet which could be our second choice to use as it consist 152 layers. This is important, because in the official paper of ResNet is said that "network depth is of crucial importance,and the leading results" [3]
#
# [3] [Deep Residual Learning for Image Recognition](https://www.cv-foundation.org/openaccess/content_cvpr_2016/papers/He_Deep_Residual_Learning_CVPR_2016_paper.pdf) (p.770)

# %% [markdown]
# With that being said, we can try the Transfer Learning technique with the InceptionV3 and ResNet models later. Right now, lets gather and clean our data
#
# # Cleaning
#
# For this part, first lets see from which sources we will mix up our final data set :
#
# A/ The official one from the Zhe Xu paper - Apart from the kaggle link provided above, it could be downloaded from [here](https://drive.google.com/file/d/0Bwo0SFiZwl3JVGRlWGZUaW5va00/edit)
#
# B/ The Marian Dumitru's one, scraped from google - [here](https://www.kaggle.com/dumitrux/architectural-styles-dataset)
#
# Both of them are doing 10113 from 25 distinct classes. However, as I said in the begining the architecture examples could be easily confused if the person who gather them do not have background knowledge. For instance, we cannot only trust Google. I found that a lot of the examples in those datasets are wrong. After I carefully and manually checked each one, they left only around 7000 photos, which is not enough. Also the different classes become very imbalanced. Thus, I decided to made a third source of images and to scrape more examples from the bing search .
#
# C/ The [Bing image](https://gist.github.com/stephenhouser/c5e2b921c3770ed47eb3b75efbc94799#file-bing-image-py) search package - I've done this step locally, as I had to use external codes and editors.

# %%
# first lets download the bing downlaoder : 
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

# %% [markdown]
# We are going to downlaod the images with a loop but first we have to load the dataset with the folders we have so far :
# - First, lets connect the notebook with the Google Colab directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os 
styles = os.listdir('/content/drive/MyDrive/DL/Project/dataset')
n_classes = (len(styles))
print(styles)
print(n_classes)
# Out:
# ['American craftsman style', 'Russian Revival architecture', 'American Foursquare architecture', 'Palladian architecture', 'Colonial architecture', 'Bauhaus architecture', 'Edwardian architecture', 'Novelty architecture', 'Postmodern architecture', 'Art Deco architecture', 'Georgian architecture', 'Tudor Revival architecture', 'Byzantine architecture', 'Queen Anne architecture', 'International style', 'Greek Revival architecture', 'Beaux-Arts architecture', 'Achaemenid architecture', 'Chicago school architecture', 'Deconstructivism', 'Gothic architecture', 'Baroque architecture', 'Art Nouveau architecture', 'Romanesque architecture', 'Ancient Egyptian architecture']
# 25

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# The loop for downloading additional images : 
for i in range(n_classes):
      downloader.download(styles[i], limit=200,  output_dir="dataset", adult_filter_off=False, force_replace=True, timeout=100)

# %% [markdown]
# # Cleaning :
# After this notebook I had to clean the wrong images manualy . The problem waas not in their size or filtering, but in their very content, which would be impossible for right sorting without a background knowledge .

# %% [markdown]
# ### H0 - My hypothesis is that from overall 15k images, a lot of them will be incorectly generated .

# %% [markdown]
# After the cleaning I have around 10k samples. Which is 2/3 of the first result . H0 is accepted.
